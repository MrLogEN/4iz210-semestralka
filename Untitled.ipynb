# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
df = pd.read_csv("./input/diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ## ÚVOD
#
# 1. Vybraný dataset se zaměřuje na diabetes u žen. Machine learning má potenciál využít datasety s informacemi o zdravotním stavu žen k predikci diabetu. Tento přístup může být zvláště užitečný pro identifikaci rizikových skupin a prevenci onemocnění. Analyzování různých atributů a vzorů v datech může pomoci lékařům a výzkumníkům lépe porozumět faktorům spojeným s rozvojem diabetu a umožnit cílenější intervence pro snížení rizika.
#
# 2. https://www.kaggle.com/code/vizeno/diabetes-prediction-8-models-eda/notebook
#
# 3. Target attribute: Outcome -> 1 = mají cukrovku, 0 = nemají cukrovku
# Instance of interest: náhodně vybraný záznam -> 123
# Atribute of interest: Glucose -> zajímá nás, jak koncentrace glukózy ovlivní výsledek
# Cost matrix: [TODO]

# %% [markdown]
# ## Data Exploration
# ### 1. Histogramy

# %%
target_hist = df.Outcome.value_counts().plot(kind='bar')
target_hist.set_title("Target variable")
target_hist.set_xlabel('Outcome')
target_hist.set_ylabel('Outcome count')
# df.Outcome.values
# Out:
# Text(0, 0.5, 'Outcome count')

# %%
plt.hist(df.Glucose, rwidth=0.9, bins=40)
plt.xlabel("Glucose level")
plt.ylabel("Frequency") 
plt.title("Glucose")
plt.show()

# %%
plt.hist(df.BloodPressure, rwidth=0.9, bins=40)
plt.xlabel("Blood Pressure")
plt.ylabel("Frequency") 
plt.title("Blood presure")
plt.show()

# %%
plt.hist(df.Insulin, rwidth=0.9, bins=40)
plt.xlabel("Insulin")
plt.ylabel("Frequency") 
plt.title("Insulin level")
plt.show()

# %%
plt.hist(df.BMI, rwidth=0.9, bins=40)
plt.xlabel("BMI")
plt.ylabel("Frequency") 
plt.title("BMI level")
# Out:
# Text(0.5, 1.0, 'BMI level')

# %%
plt.hist(df.DiabetesPedigreeFunction, rwidth=0.9, bins=40)
plt.xlabel("Diabetes Pedigree Function")
plt.ylabel("Frequency") 
plt.title("Diabetes Pedigree Function level")

# df
# Out:
# Text(0.5, 1.0, 'Diabetes Pedigree Function level')

# %%
plt.hist(df.Age, rwidth=0.9, bins=20)
plt.xlabel("Age")
plt.ylabel("Frequency") 
plt.title("Age")

# df
# Out:
# Text(0.5, 1.0, 'Age')

# %% [markdown]
# ### 2. Scatterplot

# %%
plt.scatter(df.Glucose, df.Outcome, label="Glucose", alpha=0.2)
plt.title("Glucose")
plt.xlabel("Glucose")
plt.ylabel("Outcome")
plt.show()

# %%
plt.scatter(df.Insulin, df.Outcome, label="Insulin", alpha=0.2)
plt.title("Insulin")
plt.xlabel("Insulin")
plt.ylabel("Outcome")
plt.show()

# %%
plt.scatter(df.BMI, df.Outcome, label="BMI", alpha=0.2)
plt.title("BMI")
plt.xlabel("BMI")
plt.ylabel("Outcome")
plt.show()

# %%
plt.scatter(df.DiabetesPedigreeFunction, df.Outcome, label="Diabetes Pedigree Function", alpha=0.2)
plt.title("DiabetesPedigreeFunction")
plt.xlabel("DiabetesPedigreeFunction")
plt.ylabel("Outcome")
plt.show()

# %%
plt.scatter(df.Age, df.Outcome, label="Age", alpha=0.2)
plt.title("Age")
plt.xlabel("Age")
plt.ylabel("Outcome")
plt.show()
